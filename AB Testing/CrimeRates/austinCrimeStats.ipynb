# %%
import pandas as pd
import statsmodels.api as sm

# %%
table = pd.read_csv('/Users/noahgomez/Desktop/bq-results-20260423-164835-1776962921104.csv')

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
countT, countV = [12236, 7138]
nobsT, nobsV = [85985, 25573]

count = [countT, countV]
nobs = [nobsT, nobsV]

zstat, pval = proportions_ztest(count, nobs, alternative='two-sided')

print(f'zscore: {round(zstat, 4)}')
print(f'pval: {round(pval, 4)}')
# Out:
# zscore: -50.7061
# pval: 0.0
